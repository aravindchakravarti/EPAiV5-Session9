# %%
from regularconvexpolygon import RegConvexPolygon
from polygonsequence import PolygonSequence

# %% [markdown]
# # Testing Regular Convex Polygon Functions

# %% [markdown]
# #### Create and display Regular Convex Polygon

# %%
poly_a = RegConvexPolygon(4, 4)
print(poly_a)
# Out:
# RegConvexPolygon(edges=4, circum_radius=4, interior_angle=90.00, edge_len=5.66, apothem=2.83, area=32.00, perimeter=22.63)

# %% [markdown]
# #### Check __eq__ method of RegConvexPolygon

# %%
poly_a = RegConvexPolygon(4, 4)
poly_b = RegConvexPolygon(4, 4)
print(poly_a == poly_b)
# Out:
# True

# %%
poly_a = RegConvexPolygon(4, 4)
poly_b = RegConvexPolygon(4, 5)
print(poly_a == poly_b)
# Out:
# False

# %% [markdown]
# #### Check __gt__ method of RegConvexPolygon

# %%
poly_a = RegConvexPolygon(5, 10)
poly_b = RegConvexPolygon(4, 10)
print(poly_a > poly_b)
# Out:
# True

# %%
poly_a = RegConvexPolygon(5, 10)
poly_b = RegConvexPolygon(4, 10)
print(poly_a < poly_b)
# Out:
# False

# %% [markdown]
# #### Test the Regular Convex Polygon with wrong inputs

# %%
poly_a = RegConvexPolygon('a', 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 poly_a = RegConvexPolygon('a', 4)
#
# File d:\OneDrive - ALTEN Group\Personal and Otherstuff\Learnings\EPAi5\EPAiV5-Session9\regularconvexpolygon.py:17, in RegConvexPolygon.__init__(self, edges, circum_radius)
#      13 '''
#      14 Initialize the convex polygon with its number of edges and circumradius.
#      15 '''
#      16 if not isinstance (edges, int):
# ---> 17     raise TypeError ('Polygons will have edges of type int')
#      19 if not (isinstance(edges, float) or isinstance(edges, int)):
#      20     raise TypeError ('Polygon circumradius must be either int or float')
#
# TypeError: Polygons will have edges of type int

# %%
poly_a = RegConvexPolygon(4, 'a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 poly_a = RegConvexPolygon(4, 'a')
#
# File d:\OneDrive - ALTEN Group\Personal and Otherstuff\Learnings\EPAi5\EPAiV5-Session9\regularconvexpolygon.py:19, in RegConvexPolygon.__init__(self, edges, circum_radius)
#      16 if not isinstance (edges, int):
#      17     raise TypeError ('Polygons will have edges of type int')
# ---> 19 if not (isinstance(edges, float) or isinstance(edges, int)):
#      20     raise TypeError ('Polygon circumradius must be either int or float')
#      22 if circum_radius <= 0:
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %% [markdown]
# #### Test if program raises error if less than three edges given

# %%
poly_a = RegConvexPolygon(0, 4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 poly_a = RegConvexPolygon(0, 4)
#
# File d:\OneDrive - ALTEN Group\Personal and Otherstuff\Learnings\EPAi5\EPAiV5-Session9\regularconvexpolygon.py:23, in RegConvexPolygon.__init__(self, edges, circum_radius)
#      20     raise ValueError ('Polygon\'s circum radius must a valid positive real number')
#      22 if edges < 3:
# ---> 23     raise ValueError ('Polygon should have atleast 3 sides')
#      25 self.no_edges = edges
#      26 self.circum_radius = circum_radius
#
# ValueError: Polygon should have atleast 3 sides

# %%
poly_a = RegConvexPolygon(-1, 4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 poly_a = RegConvexPolygon(-1, 4)
#
# File d:\OneDrive - ALTEN Group\Personal and Otherstuff\Learnings\EPAi5\EPAiV5-Session9\regularconvexpolygon.py:23, in RegConvexPolygon.__init__(self, edges, circum_radius)
#      20     raise ValueError ('Polygon\'s circum radius must a valid positive real number')
#      22 if edges < 3:
# ---> 23     raise ValueError ('Polygon should have atleast 3 sides')
#      25 self.no_edges = edges
#      26 self.circum_radius = circum_radius
#
# ValueError: Polygon should have atleast 3 sides

# %% [markdown]
# # Testing Polygon Sequence

# %% [markdown]
# #### Create and print correct Polygon Sequence

# %%
poly_seq_a = PolygonSequence(3.2, 5)
print(poly_seq_a)
# Out:
# PolygonSequence(largest_polygon=5, polygon with area to perimeter ratio from 3 to 5=[0, 0, 0, 0.8000000000000003, 1.1313708498984762, 1.294427190999916])

# %% [markdown]
# #### Check which polygon has highest area to perimeter ratio

# %%
# largest_area_to_perimeter_ratio returns the area to perimeter ratio and the polygon for which it was highest
poly_seq_a.largest_area_to_perimeter_ratio()
# Out:
# 1.294427190999916 5

# %% [markdown]
# #### Check with wrong inputs

# %%
poly_seq_a = PolygonSequence('a', 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 poly_seq_a = PolygonSequence('a', 5)
#
# File d:\OneDrive - ALTEN Group\Personal and Otherstuff\Learnings\EPAi5\EPAiV5-Session9\polygonsequence.py:12, in PolygonSequence.__init__(self, circum_radius, largest_polygon)
#       9 if not isinstance(largest_polygon, int):
#      10     raise TypeError('Expected largest polygon as type int')
# ---> 12 if circum_radius <=0 :
#      13     raise ValueError('Circum Radius must a valid positive number')
#      15 if largest_polygon < 3:
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
poly_seq_a = PolygonSequence(0.0, 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 poly_seq_a = PolygonSequence(0.0, 5)
#
# File d:\OneDrive - ALTEN Group\Personal and Otherstuff\Learnings\EPAi5\EPAiV5-Session9\polygonsequence.py:13, in PolygonSequence.__init__(self, circum_radius, largest_polygon)
#      10     raise TypeError('Expected largest polygon as type int')
#      12 if circum_radius <=0 :
# ---> 13     raise ValueError('Circum Radius must a valid positive number')
#      15 if largest_polygon < 3:
#      16     raise ValueError('Polygons are defined only with 3 or more edges')
#
# ValueError: Circum Radius must a valid positive number

# %%
poly_seq_a = PolygonSequence(0.1, 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 poly_seq_a = PolygonSequence(0.1, 2)
#
# File d:\OneDrive - ALTEN Group\Personal and Otherstuff\Learnings\EPAi5\EPAiV5-Session9\polygonsequence.py:16, in PolygonSequence.__init__(self, circum_radius, largest_polygon)
#      13     raise ValueError('Circum Radius must a valid positive number')
#      15 if largest_polygon < 3:
# ---> 16     raise ValueError('Polygons are defined only with 3 or more edges')
#      18 self.circum_radius = circum_radius
#      19 self.largest_polygon = largest_polygon
#
# ValueError: Polygons are defined only with 3 or more edges

# %% [markdown]
# #### Check __len__ property of PolygonSequence

# %%
poly_seq_a = PolygonSequence(3.2, 15)
print(len(poly_seq_a))
# Out:
# 16

# %% [markdown]
# #### Check __getitem__ of the PolygonSequence

# %%
poly_seq_a = PolygonSequence(3.2, 25)

for index, value in enumerate (poly_seq_a):
    print(f'For edge {index} area to perimeter ratio = {value}')
# Out:
# For edge 0 area to perimeter ratio = 0
# For edge 1 area to perimeter ratio = 0
# For edge 2 area to perimeter ratio = 0
# For edge 3 area to perimeter ratio = 0.8000000000000003
# For edge 4 area to perimeter ratio = 1.1313708498984762
# For edge 5 area to perimeter ratio = 1.294427190999916
# For edge 6 area to perimeter ratio = 1.385640646055102
# For edge 7 area to perimeter ratio = 1.4415501886438706
# For edge 8 area to perimeter ratio = 1.478207252018059
# For edge 9 area to perimeter ratio = 1.5035081932574537
# For edge 10 area to perimeter ratio = 1.5216904260722457
# For edge 11 area to perimeter ratio = 1.535188757783196
# For edge 12 area to perimeter ratio = 1.5454813220625094
# For edge 13 area to perimeter ratio = 1.5535069078816832
# For edge 14 area to perimeter ratio = 1.559884659490918
# For edge 15 area to perimeter ratio = 1.5650361611740893
# For edge 16 area to perimeter ratio = 1.5692564486451688
# For edge 17 area to perimeter ratio = 1.572756959494243
# For edge 18 area to perimeter ratio = 1.5756924048195329
# For edge 19 area to perimeter ratio = 1.578178085444356
# For edge 20 area to perimeter ratio = 1.5803013449522205
# For edge 21 area to perimeter ratio = 1.5821293219602057
# For edge 22 area to perimeter ratio = 1.5837143070094923
# For edge 23 area to perimeter ratio = 1.5850975136581293
# For edge 24 area to perimeter ratio = 1.5863117781980967
# For edge 25 area to perimeter ratio = 1.5873835221031647
